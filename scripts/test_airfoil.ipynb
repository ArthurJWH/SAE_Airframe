# %% [markdown]
# ## Testing airfoil generation and plotting

# %%
using MyPackage.Geometry
using MyPackage.MyPlots

# %%
naca2412 = Airfoil("../assets/airfoils/NACA2412/NACA2412.dat")
plot_airfoil(naca2412, save=true)
# Out:
# Loading airfoil: NACA2412 from ../assets/airfoils/NACA2412/NACA2412.dat

# %%
s1223 = Airfoil("../assets/airfoils/S1223/S1223.dat")
plot_airfoil(s1223, save=true)
# Out:
# Loading airfoil: S1223 from ../assets/airfoils/S1223/S1223.dat

# %%
esa40 = Airfoil("../assets/airfoils/ESA40/ESA40.dat")
plot_airfoil(esa40, save=true)
# Out:
# Loading airfoil: ESA40 from ../assets/airfoils/ESA40/ESA40.dat

# %%
plain = Airfoil("../assets/airfoils/Plain/Plain.dat")
plot_airfoil(plain, save=true)
# Out:
# Loading airfoil: Plain from ../assets/airfoils/Plain/Plain.dat
